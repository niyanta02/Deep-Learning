# %% [markdown]
# <a href="https://colab.research.google.com/github/niyanta02/Deep-Learning/blob/main/Multi_Layer_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("perceptron_dataset_2feature.csv")

# %%
df.head()
# Out:
#    feature1  feature2  label
# 0     1.643     3.685      0
# 1     1.519     4.482      0
# 2     1.617     2.851      0
# 3     6.546     6.752      1
# 4     7.014     6.434      1

# %%
df.shape
# Out:
# (200, 3)

# %%
df.isnull().sum()
# Out:
# feature1    0
# feature2    0
# label       0
# dtype: int64

# %%
sns.scatterplot(x='feature1', y='feature2', hue='label', data=df)
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#      feature1  feature2
# 0       1.643     3.685
# 1       1.519     4.482
# 2       1.617     2.851
# 3       6.546     6.752
# 4       7.014     6.434
# ..        ...       ...
# 195     6.763     7.521
# 196     1.519     2.767
# 197     1.821     3.571
# 198     6.258     6.338
# 199     4.898     6.250
#
# [200 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 195    1
# 196    0
# 197    0
# 198    1
# 199    1
# Name: label, Length: 200, dtype: int64

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[7.832, 0.395]])

# %%
p.intercept_
# Out:
# array([-29.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.values, y.values, p)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
